# %% [markdown]
# <a href="https://colab.research.google.com/github/A105010148/-Computational-Thinking-and-Programming-Design/blob/main/%E9%82%B1%E9%9D%96%E5%82%91_%E6%9C%9F%E6%9C%AB%E4%BD%9C%E6%A5%ADver_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("歡迎來到這裡。")
name = input("告訴我你的名字嗎： ")
print(f"你好 {name}，讓我重新隆重的歡迎你參加這個遊戲。")
print("我名叫三木，是一名僧人。")
print("這次邀請你，是想讓你透過催眠，體驗我一次驚心動魄的遭遇。")
print("放心。只要按照我的引導，一定可以很順利進行的。")
print("再者，如果你在催眠中遇到危機，我會將你喚醒。")
...
...
...
print("事前說明就到此結束。接著讓我問你一個問題...")
answer = input("願意參加這個遊戲嗎(YES/NO)： ")
...
...
...
if answer == "YES":
  print("好的，那我馬上開始為你催眠。請你放輕鬆。")
  print("時間要回溯到距離現在30年前的1990年代...")
  print("那時你是一名修行中的僧人。從大阪來到關東地區的一間佛寺。")
  print("修行十分辛苦且無趣。")
  print("利用空閒時間在佛寺周圍地區冒險，是你為數不多的消遣。")
  print("你非常喜歡狗狗，尤其是哈士奇一類的大型犬。你發現附近有一家犬舍。")
  print("名字有點特別，叫「非洲隧道」。")
  print("自從發現它以後，只要有空閒時間，你就會去犬舍看看那些狗狗。")
  
  goornot1 = input("這天下午正巧有空。要去犬舍瞧瞧嗎（YES/NO)： ")
  if goornot1 == "YES":
    print("你走近犬舍一看，發現一群毛色發亮的大型犬。悠遊自在地曬著陽光。")
    print("你靠近那些狗，忍不住伸手摸了摸牠們，牠們也高興地舔著你的手。")
    print("正當你十分享受時，一名中年男子走向你...")
    
    print("男子問我「你很喜歡狗？」，我點點頭。")
    print("並且我向他說明我是一個修行中的僧侶，來到犬舍跟狗狗們互動，讓我很放鬆。")
    print("這男子似乎是犬舍的老闆。他聽了笑笑地鼓勵我，並說隨時歡迎我過來。")
    print("老闆將我引進了他的辦公室，桌子上擺放著三瓶普通的罐裝咖啡。")
    
    print("老闆笑著說，你累了吧。挑一瓶拿來喝吧。")
    print("你伸手將三個瓶子都摸了摸，是從冰箱拿出來，還帶有點微微冰的狀態。")
    print("你決定從善如流，挑走一瓶...")
    choice1 = int(input("左邊的瓶子［1］中間的瓶子［2］右邊的瓶子［3］： "))
    import random
    surpirse1 = random.randint(1,3)
    print("只有", surpirse1, "那瓶是沒有毒的！" )
    
    if choice1 == surpirse1:
      print("你拿起咖啡，咕嚕咕嚕地喝個精光...")
      print("喝完，你用手抹了抹嘴，還一副意猶未盡的樣子。")
      print("老闆就這麼饒富趣味地看著我把咖啡喝完。接著他問我...")
      print("「你要不要來我這邊打工？工作內容就是每個禮拜一天來陪我聊天，帶那些狗去散步。")
      print("「每個禮拜我給你十萬日圓。」")
      print("天啊！十萬圓！？你嚇壞了，自己是哪裡修得的福氣有這麼好的機會。")
      workornot = input("你要答應老闆的邀請，在犬舍打工嗎（YES/NO)： ")
      if workornot == "YES":
        print("你難掩興奮地說你很有意願，但你必須先請示過佛寺的舍監")
        print("你說回去請示過後，第二天再來跟老闆回報。")
        print("老闆笑了笑表示認可。你便離開了犬舍。")
        print("你一回到宿舍，便向舍監表明想要去犬舍打工的意思。")
        print("沒想到你話還沒說完，舍監就厲聲反對，表示刻苦修行是為了去除此種雜念。")
        print("舍監讓你寫了悔過書，還讓你在其他人面前朗讀，你感到十分難受。")
        print("你為了轉達詢問的結果，也不得不再前往犬舍一趟。帶著這樣的難受與不安，你就這麼睡著了。")
        ...
        ...
        ...
        print("隔天下午，結束了早上更為辛苦的日課後，你帶著忐忑不安的心情來到犬舍。")
        print("看了看犬舍辦公室的門，還有犬舍圍欄裡可愛的狗狗們...")
        officeordog = input("你是要直接前去辦公室找老闆［OFFICE］或是先和犬舍的狗狗們玩耍［DOG］： ")
        ...
        ...
        if officeordog == "OFFICE":
          print("你決定直接前往辦公室。你敲了敲門，聽到裡面有人應聲，就推開門走了進去。")
          print("看見你來到，老闆顯得有點驚訝。詢問你昨天的結果如何。")
          print("你非常沮喪地轉述了前一天詢問的結果，並鄭重地向老闆道了歉。")
          print("但老闆顯得有點心神不寧，只是隨便地敷衍著，說他再找其他人就好。")
          print("這時你將視線放到了老闆辦公桌上的三瓶咖啡。")
          print("老闆似乎是注意到你的眼神，非常大方的再讓你挑一瓶咖啡。")
          print("你伸手摸了摸，只有右邊那瓶是常溫的，其他兩瓶都是和上次一樣微冰。")
          print("老闆笑呵呵地說「不用挑了，味道都是一樣好的。」")
          choice2 = input("左邊的瓶子［1］中間的瓶子［2］右邊的瓶子［3］： ")
          import random
          surprise2 = random.randint(1,2)
          ...
          ...
          if choice2 == surprise2:
            print("你再次舉起瓶子咕嚕咕嚕地享用完整瓶咖啡。雖然不冰，但喝起來也不差。")
            print("但老闆以接下來要打掃犬舍為由，暗示著你可以走了。")
            print("當你要告辭時，老闆說，這裡依舊歡迎著你。")
            ...
            ...
            ...
            print("接下來很長一段時間，也許是因為舍監盯你盯得更緊、也許是出於毀約的罪惡感...")
            print("你都沒有再拜訪犬舍。")
            print("一個月後，你在關東這間佛寺的修行，算是吿了一個段落。")
            print("你想著過去在犬舍放鬆的時光，覺得必須前去跟老闆道個別。")
            ...
            ...
            print("你來到了犬舍。犬舍裡的狗狗們看見你久違來到，又是搖尾巴、又是吠聲地歡迎你。")
            print("你摸著牠們每一隻的頭，想著應該很久不能再見面，有點悲從中來，對牠們說「謝謝你們。」")
            print("跟狗狗們道別完後，你前往老闆的辦公室。")
            print("老闆看到你顯得十分驚訝，隨口說著「哎呀多久沒看到你來啦。」")
            print("你跟他說，自己接下來要到別的地方修行，離關東很遠，這段時間謝謝老闆的關照等等。")
            print("老闆笑笑地說，他覺得你很不一樣，你不能來當然很可惜，但這裡的大門永遠為你敞開。")
            print("老闆突然從辦公桌抽屜裡拿出三瓶咖啡，將它們在桌子上排開。")
            print("並用眼神示意我挑一瓶，就與往常一樣。")
            print("我也和往常一樣，將每瓶都摸了摸，因為是從抽屜拿出來，所以它們當然都是常溫的。")
            print("我看著老闆的臉，看起來我是一定得挑一瓶了。")
            choice3 = input("左邊的瓶子［1］中間的瓶子［2］右邊的瓶子［3］： ")
            import random
            surprise3 = random.randint(1,3)
            print("最後的選擇沒有毒的是——", surprise3, "那瓶！")
            if choice3 == surprise3:
              print("我咕嚕咕嚕地喝完咖啡後，老闆看著我，問")
              print("「你...相信有神佛存在是嗎？」")
              print("任何人都知道，我是一名僧人，竟然有人問我這個問題，換我被嚇到了。")
              print("我說是啊，這就是我修行的目的。")
              print("老闆說「這樣啊。說得也是。」")
              print("我要離開時，再向老闆道了一次謝，老闆也對我說，到哪裡都要好好加油。")
              print("我們便道了別。從此我再也沒見過他，直到...")
              ...
              ...
              ...
              print("...你醒了嗎？")
              print("恭喜你至此算是破了關。什麼？你問我那個老闆後來怎麼了？")
              wanttoknow = input("你真的想知道？（YES/NO）： ")
              if wanttoknow == "YES":
                print("好吧，那我就告訴你。")
                print("我的確很長一段時間都沒有再看到那個老闆。")
                print("後來我在電視上看到一個兇殺案的嫌犯的臉，我突然嚇到")
                print("那不是那個老闆的臉嗎！？")
                print("後來那個老闆還被判了死刑。我有個前輩在監獄裡當教誨師")
                print("他在和我們聊天時說，他有輔導一個死刑犯")
                print("那個老頭很臭屁地說，他有七大哲學，還專門殺運氣不好的傢伙。")
                print("聽到這裡我就忍不住問，什麼叫運氣不好的傢伙？")
                print("前輩說，那個老頭說，他以前遇到過一個毛頭小和尚。")
                print("那個小和尚每次來，他就請他喝咖啡，三瓶裡面只有一瓶是沒有毒的。")
                print("令他萬萬沒有想到，那個和尚竟然三次都挑到沒有毒的咖啡。")
                print("那個死刑犯說，就在那時，他覺得神佛應該是真的存在在這個世界上吧。")
                ...
                ...
                ...
                print("對的。那個小和尚就是我，三木。")
                print("噢，對了。也是你啊。因為你成功體驗了我的回憶嘛。")
                print("這次真的謝謝你願意陪我玩這個無聊的遊戲。不如我請你喝瓶咖啡吧？")
                print("開玩笑的，開玩笑的！哈哈。")
                print("辛苦了。我們下次見吧！")
              else:
                print("你不想聽嗎。這也沒有關係。")
                print("這次真的謝謝你願意陪我玩這個遊戲。")
                print("辛苦你了。希望下次再見！")
            else:
              print("我咕嚕咕嚕地喝下咖啡，當我回過神來，我鼻子竟然血流不止。")
              print("不止如此，我雙腿發軟，全身各個部位都在痛，但我完全叫不出聲。")
              print("「呵呵呵...。再怎麼會選，也就到今天為止了。」")
              print("「還以為這次該不會又被你該死的矇到，看你這副慘況，真是可憐啊。」")
              print("在我失去意識之前，就聽到有個聲音嘀咕著這些...。")
              ...
              ...
              print("...你醒過來了嗎？")
              print("最後就差一點點了呢。真是可惜。")
              print("最後一關要靠真本事，我是這樣覺得的。下次再來挑戰吧。")
          else:
            print("你再次舉起瓶子咕嚕咕嚕地享用完整瓶咖啡。")
            print("突然胸口像是被人重擊一樣有著深切的痛楚。你甚至痛得哭了出來。")
            print("你看見老闆嘴角露出一抹冷笑，他說...")
            print("「都放水成這樣還挑不出來，這是你的佛祖要你的命啊。」")
            ...
            ...
            print("...你醒過來了嗎？")
            print("嗯...，忽略了提示，的確十分可惜啊。")
            print("今天這樣就可以了，你回家好好休息吧。期待下次相見。")

        elif officeordog == "DOG":
          print("你和往常一樣，跟著狗兒們一同玩耍，不知不覺時間就這麼過去...")
          print("這時你回神，突然感覺背後有人靠近，老闆將手搭在你的肩膀上。")
          print("老闆熱情的招呼你，說是外面太熱了，將你帶進了辦公室。")
          print("你非常沮喪地轉述了前一天詢問的結果，並鄭重地向老闆道了歉。")
          print("但老闆只是漫不用心地應付著，說「沒關係，我再找其他人就好。」")
          print("當你準備要告辭時，老闆又讓你拿一瓶咖啡去喝。")
          print("這次與上次一樣有三瓶。你伸手摸了摸，也都是微冰的。")
          print("老闆笑瞇瞇地慈祥地說「不用挑了，都是一樣的，挑一瓶拿去解渴吧！」")
          ...
          ...
          alternative_choice2 = input("左邊的瓶子［1］中間的瓶子［2］右邊的瓶子［3］： ")
          import random
          alternative_surprise2 = random.randint(1,3)
          print("這次只有", surprise2, "那瓶是沒有毒的嗎？")
          ...
          ...
          if alternative_choice2 == alternative_surprise2:
            print("你再次舉起瓶子咕嚕咕嚕地享用完整瓶咖啡。")
            print("老闆繼續跟你閒話家常著，等你要離開時，老闆說，這裡依舊歡迎你。")
            ...
            ...
            print("接下來很長一段時間，也許是因為你知道去犬舍放鬆是違背修行的、也許是因為害怕給犬舍添麻煩。")
            print("你都沒有再去拜訪犬舍。")
            print("一個月後，你在此地的修行即將告一個段落。")
            print("你內心覺得犬舍的人們與狗狗照顧了你很多，你必須去道個別，這樣才有禮貌。")
            ...
            ...
            print("隔天，你來到犬舍。看見哈士奇雪白的毛被陽光灑成金黃色的，十分好看。")
            print("你摸著狗狗們的頭，牠們也熱情地舔著你，你回憶起這段時光，對牠們說了一聲「謝謝。」")
            print("接著你為了向老闆道別，前往他的辦公室。")
            print("老闆看到你隔了這麼久時間，突然又出現。顯得十分驚訝。")
            print("老闆又是問我怎麼這麼久沒來，又是問我這段時間好不好，讓我覺得十分溫暖。")
            print("我向老闆表示，我接下來要轉往離這裡有點距離的地方修行了。謝謝他與狗狗們的照顧。")
            print("老闆嘆了口氣說，他還想多跟我聊聊，我就這麼走了，真的非常可惜。")
            print("老闆的辦公桌上與以前一樣擺放著三瓶罐裝咖啡。老闆也讓我挑一瓶走。")
            print("我摸了摸，這些咖啡與以前一樣，都是帶點微冰的。")
            print("老闆笑呵呵地說「你一定渴了吧，來！來！挑一瓶吧。」")
            ...
            ...
            alternative_choice3 = input("左邊的瓶子［1］中間的瓶子［2］右邊的瓶子［3］： ")
            import random
            alternative_surprise3 = random.randint(1,3)
            print("最後的選擇，沒有毒的那瓶是...", alternative_surprise3, "那瓶。")
            ...
            ...
            if alternative_choice3 == alternative_surprise3:
              print("我咕嚕咕嚕地飲完咖啡。老闆正視良久，問")
              print("「你相信這世界上有神啊、佛啊之類的東西嗎？」")
              print("我反射性的回答說，我相信啊，不然我也就不會修行了。")
              print("老闆聽了我的回答，點了點頭，說我會這樣覺得也是正常的。")
              print("當時間差不多，我準備要離開時，我再次向老闆道了個謝。")
              print("而老闆也說，我到哪裡應該都可以很順遂，要我好好加油。")
              print("至此，我就再也沒看過這個老闆了。")
              print("正當我這麼想的時候...")
              ...
              ...
              ...
              print("...你醒過來了嗎？")
              print("恭喜你。到這邊就算是過關了。")
              print("你說我後來是不是見過老闆？你想知道後來的故事嗎？")
              wanttoknow2 = input("你真的想知道，還是在說客套話？（YES/NO)： ")
              if wanttoknow2 == "YES":
                print("好吧。那我就接著說下去。")
                print("後來我到了別的地方修行，當然也就沒看到老闆。")
                print("大約在幾年後，電視上播放著一對夫妻為了錢財而殺害6人的新聞")
                print("我看到那個男性嫌犯的臉，突然驚覺，那不就是那個犬舍的老闆嗎！？")
                print("那個時候我簡直快嚇壞了...。")
                ...
                ...
                print("後來那對夫妻被判了死刑，關在東京的監獄裡。")
                print("我有個前輩，他在東京監獄裡負責輔導死刑犯。他在跟我們聊天時")
                print("分享他在獄中遇到過一個六七十歲的犯人，這個犯人說他有七大原則")
                print("譬如不會因為保險金殺人、專殺運氣不好的傢伙等等")
                print("我忍不住好奇的問，什麼叫運氣不好的傢伙？")
                print("前輩說，幾十年前，有個小和尚常常去那個死刑犯經營的犬舍。")
                print("那個犯人每次他來，都請他喝咖啡，三瓶裡面有兩瓶是有毒的。")
                print("沒想到那個小和尚，三次都剛好挑到沒有毒的。")
                print("那個犯人說到這有點自嘲地說，這次我真的得信佛了。否則哪有這麼扯的。")
                ...
                ...
                ...
                print("跟你想的一樣，是的，我覺得那個犯人講的和尚就是我。")
                print("你也是啊。畢竟你跟我一樣，都生存下來了呢。")
                print("這次真的很謝謝你，看著你體會我所體會過的，我也覺得很有趣。")
                print("剛好我這邊也有三瓶罐裝咖啡，你要不要帶一瓶回去？")
                print("你怎麼跑這麼快？哈哈。我只是開玩笑的！")
                print("好啦，下次再來啦！")
              else:
                print("你沒有興趣啊。總覺得有點可惜呢。")
                print("今天謝謝你，也辛苦你了。")
                print("下次再玩吧！")
            else:
              print("我咕嚕咕嚕地將咖啡一口一口地送進喉嚨。")
              print("突然這裡痛、那裡痛。很快地，全身都在痛，根本束手無策。")
              print("老闆「呸」了一口，不屑地說「還以為這次能逃掉？你是贏不過我的。」")
              print("見你的冥王去吧！記得，不要炫耀自己的狗屎運，別笑死人了。」")
              print("我就這麼聽著老闆罵著這些，我突然感覺不到痛，慢慢地像睡著一樣...")
              ...
              ...
              print("...你醒過來了嗎？")
              print("最後的最後，就差這麼一步，一定很不甘心吧。")
              print("我相信下次的你一定可以。你一定要再來挑戰哦！")

          else:
            print("你再次舉起瓶子咕嚕咕嚕地享用完整瓶咖啡。")
            print("但下一秒你卻感覺全身肌肉都在劇烈地陣痛，喉嚨像是火在燒。")
            print("你聽到一個跟老闆很像的聲音在惡狠狠的說「哼！上次看來只是走狗屎運而已。」")
            ...
            ...
            print("...你醒過來了嗎？")
            print("看來這次運氣不是很好呢... 是不是做了什麼錯誤的選擇呢？")
            print("你回去好好休息。下次再過來吧。")
        else:
          print("你選擇不去辦公室，也不去犬舍跟狗玩，而是離開了犬舍。")
          print("沒想到在你徒步到地鐵站的路上竟遇到黑道火拼。")
          print("流彈就這麼剛好打到了你的肚子，在激烈的槍聲中，你的意識逐漸散去...")
          ...
          ...
          print("...你醒過來了嗎？")
          print("選第三選項是不會有好事的，我可以這麼跟你說！")
          print("你回家好好睡個覺吧。相信下次你會做出更好的選擇。")

      else:
        ...
        ...
        print("...你醒過來了嗎？")
        print("你拒絕了老闆的邀約，坐上地鐵要搭到佛寺附近的地鐵站時。")
        print("跟你在地鐵的同個車廂裡，竟然有個打算實施隨機犯案的失意男子。")
        print("你成為他最先下手的目標...。真是難以言喻啊...。")
        print("今天先這樣吧。期待下次再看到你。")
    else:
      print("你拿起咖啡，咕嚕咕嚕地喝個精光...")
      print("喝完，你用手抹了抹嘴。突然，你感覺突然喘不過氣。")
      print("四肢無力，你再也站不住而趴了下去，還伴隨著一陣陣的乾嘔。")
      print("在逐漸朦朧的意識逝去前，你仿佛聽到...")
      print("「嘖！第一關就不行了嗎？哎呀哎呀，今晚又有得忙了啊...」")
      ...
      ...
      print("...你醒過來了嗎？")
      print("看來你喝到有毒的咖啡了。")
      print("接下來發生什麼事，不用說你也知道，實在太可怕了。")
      print("今天先這樣吧。希望下次你可以更順利。")

  else:
    ...
    ...
    ...
    print("...你醒過來了嗎？")
    print("你在另外一條路被煞車失靈的大卡車撞上。")
    print("在你嚥氣以前，我將你喚醒了。")
    ...
    ...
    print("今天先這樣吧。下次再來，做出正確的判斷。")

elif answer == "NO":
  print("真是可惜...。歡迎你下次再來。")
else:
  print("你的回答似乎有誤。請再重新來過，謝謝。")
# Out:
# 歡迎來到這裡。
# 告訴我你的名字嗎： 鄭靖榆
# 你好 鄭靖榆，讓我重新隆重的歡迎你參加這個遊戲。
# 我名叫三木，是一名僧人。
# 這次邀請你，是想讓你透過催眠，體驗我一次驚心動魄的遭遇。
# 放心。只要按照我的引導，一定可以很順利進行的。
# 再者，如果你在催眠中遇到危機，我會將你喚醒。
# 事前說明就到此結束。接著讓我問你一個問題...
# 願意參加這個遊戲嗎(YES/NO)： YES
# 好的，那我馬上開始為你催眠。請你放輕鬆。
# 時間要回溯到距離現在30年前的1990年代...
# 那時你是一名修行中的僧人。從大阪來到關東地區的一間佛寺。
# 修行十分辛苦且無趣。
# 利用空閒時間在佛寺周圍地區冒險，是你為數不多的消遣。
# 你非常喜歡狗狗，尤其是哈士奇一類的大型犬。你發現附近有一家犬舍。
# 名字有點特別，叫「非洲隧道」。
# 自從發現它以後，只要有空閒時間，你就會去犬舍看看那些狗狗。
# 這天下午正巧有空。要去犬舍瞧瞧嗎（YES/NO)： YES
# 你走近犬舍一看，發現一群毛色發亮的大型犬。悠遊自在地曬著陽光。
# 你靠近那些狗，忍不住伸手摸了摸牠們，牠們也高興地舔著你的手。
# 正當你十分享受時，一名中年男子走向你...
# 男子問我「你很喜歡狗？」，我點點頭。
# 並且我向他說明我是一個修行中的僧侶，來到犬舍跟狗狗們互動，讓我很放鬆。
# 這男子似乎是犬舍的老闆。他聽了笑笑地鼓勵我，並說隨時歡迎我過來。
# 老闆將我引進了他的辦公室，桌子上擺放著三瓶普通的罐裝咖啡。
# 老闆笑著說，你累了吧。挑一瓶拿來喝吧。
# 你伸手將三個瓶子都摸了摸，是從冰箱拿出來，還帶有點微微冰的狀態。
# 你決定從善如流，挑走一瓶...
# 左邊的瓶子［1］中間的瓶子［2］右邊的瓶子［3］： 2
# 只有 2 那瓶是沒有毒的！
# 你拿起咖啡，咕嚕咕嚕地喝個精光...
# 喝完，你用手抹了抹嘴，還一副意猶未盡的樣子。
# 老闆就這麼饒富趣味地看著我把咖啡喝完。接著他問我...
# 「你要不要來我這邊打工？工作內容就是每個禮拜一天來陪我聊天，帶那些狗去散步。
# 「每個禮拜我給你十萬日圓。」
# 天啊！十萬圓！？你嚇壞了，自己是哪裡修得的福氣有這麼好的機會。
# 你要答應老闆的邀請，在犬舍打工嗎（YES/NO)： YES
# ...
